# %% [markdown]
# **Theory**
#
# Q1) What is NumPy, and why is it widely used in Python?
# - NumPy is a powerful library used for numerical computing in Python.
# - It provides fast and efficient multi-dimensional arrays and mathematical functions.
# - It is widely used because it is much faster than normal Python lists for calculations.
#
# Q2)  How does broadcasting work in NumPy?
# - Broadcasting allows NumPy to perform operations on arrays of different shapes.
# Instead of looping manually, NumPy automatically expands smaller arrays.
# This makes calculations easier, cleaner, and much faster.
#
# Q3)  What is a Pandas DataFrame?
# - A DataFrame is a table-like structure in Pandas with rows and columns.
# It is similar to an Excel sheet or a database table.
# It helps store, clean, and analyze structured data easily.
#
# Q4) Explain the use of the groupby() method in Pandas?
# - The groupby() method is used to group data based on some condition.
# It is commonly used to calculate sums, averages, and counts per group.
# For example, grouping salary by department.
#
# Q5) Why is Seaborn preferred for statistical visualization?
# - Seaborn is built on top of Matplotlib and focuses on statistics.
# It produces beautiful, clean, and meaningful plots with less code.
# It is perfect for analyzing relationships between variables.
#
# Q6)  What are the differences between NumPy arrays and Python lists?
# - NumPy arrays store only one data type, while lists store multiple types.
# Arrays are faster and use less memory than lists.
# Arrays also support advanced mathematical operations directly.
#
# Q7) What is a heatmap, and when should it be used?
# - A heatmap is a color-coded table that shows data intensity.
# It is often used to show correlations between variables.
# It helps quickly identify patterns and trends in data.
#
# Q8)  What does the term "vectorized operation" mean in NumPy?
# - Vectorized operations mean performing calculations on entire arrays at once.
# No loops are required for each element.
# This makes computations extremely fast and efficient.
#
# Q9) How does Matplotlib differ from Plotly?
# - Matplotlib creates static images mostly used in reports.
# Plotly creates interactive graphs that you can zoom and hover over.
# Plotly is more suitable for dashboards and web apps.
#
# Q10) What is the significance of hierarchical indexing in Pandas?
# - Hierarchical indexing allows multiple index levels in rows or columns.
# It helps manage complex, multi-dimensional data easily.
# It is very useful for advanced data analysis.
#
# Q11)  What is the role of Seaborn's pairplot() function?
# - pairplot() shows relationships between all numerical columns in a dataset.
# It creates multiple scatter plots and histograms automatically.
# It is great for quick exploratory data analysis.
#
# Q12)  What is the purpose of the describe() function in Pandas?
# - The describe() function gives a statistical summary of the data.
# It shows count, mean, min, max, and standard deviation.
# It helps understand the dataset quickly.
#
# Q13) Why is handling missing data important in Pandas?
# - Missing data can give wrong analysis results.
# It may cause errors in calculations or graphs.
# Cleaning missing data ensures accurate and reliable results.
#
# Q14)  What are the benefits of using Plotly for data visualization?
# - Plotly creates interactive and visually attractive charts.
# It supports dashboards, web apps, and real-time data.
# Users can zoom, hover, and filter data easily.
#
# Q15)  How does NumPy handle multidimensional arrays?
# - NumPy supports arrays with any number of dimensions.
# These arrays are stored in a structured, optimized way.
# It allows fast matrix operations and scientific computing.
#
# Q16)  What is the role of Bokeh in data visualization?
# - Bokeh is used for creating interactive web-based visualizations.
# It is great for live dashboards and browser-based charts.
# It works well with large and streaming datasets.
#
# Q17)  Explain the difference between apply() and map() in Pandas?
# - map() is used for transforming values in a single column.
# - apply() works on rows or columns of the DataFrame.
# - apply() is more flexible than map().
#
# Q18) What are some advanced features of NumPy?
# - NumPy supports linear algebra, Fourier transforms, and random sampling.
# It allows memory-efficient storage using views.
# It also integrates smoothly with machine learning libraries.
#
# Q19)  How does Pandas simplify time series analysis?
# - Pandas has built-in support for dates and timestamps.
# It allows easy resampling, shifting, and rolling averages.
# This makes time-based analysis simple and powerful.
#
# Q20)  What is the role of a pivot table in Pandas?
# - Pivot tables summarize large datasets.
# - They help calculate totals, averages, and counts quickly.
# - They are commonly used for reports and business analysis.
#
# Q21) Why is NumPy's array slicing faster than Python’s list slicing?
# - NumPy slicing works at the memory level.
# - It returns views instead of copying data.
# - This makes it much faster and memory-efficient.
#
# Q22) What are some common use cases for Seaborn?
# - Data exploration and visualization in machine learning.
# - Displaying distributions, correlations, and trends.
# - Creating high-quality statistical plots easily.

# %% [markdown]
# **Practical**

# %% [markdown]
# Q10  How do you create a 2D NumPy array and calculate the sum of each row?

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

row_sum = arr.sum(axis=1)
print("Row-wise sum:", row_sum)
# Out:
# Row-wise sum: [ 6 15]

# %% [markdown]
# Q2)  Write a Pandas script to find the mean of a specific column in a DataFrame?

# %%
import pandas as pd

data = {
    "age": [20, 25, 30, 35],
    "salary": [30000, 40000, 50000, 60000]
}

df = pd.DataFrame(data)
mean_salary = df["salary"].mean()
print("Mean Salary:", mean_salary)
# Out:
# Mean Salary: 45000.0

# %% [markdown]
# Q3)  Create a scatter plot using Matplotlib.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.scatter(x, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Q4)  How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Math": [85, 90, 88, 92],
    "Science": [80, 85, 89, 95],
    "English": [78, 82, 85, 88]
}

df = pd.DataFrame(data)

corr = df.corr()

sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Q5)  Generate a bar plot using Plotly.

# %%
import plotly.express as px

x = ["A", "B", "C", "D"]
y = [10, 20, 15, 25]

fig = px.bar(x=x, y=y, title="Bar Plot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Q6) Create a DataFrame and add a new column based on an existing column.

# %%
import pandas as pd

df = pd.DataFrame({
    "price": [100, 200, 300]
})

df["discounted_price"] = df["price"] * 0.9
print(df)
# Out:
#    price  discounted_price
# 0    100              90.0
# 1    200             180.0
# 2    300             270.0

# %% [markdown]
# Q7) Write a program to perform element-wise multiplication of two NumPy arrays?

# %%
import numpy as np

a = np.array([2, 4, 6])
b = np.array([1, 3, 5])

result = a * b
print("Element-wise multiplication:", result)
# Out:
# Element-wise multiplication: [ 2 12 30]

# %% [markdown]
# Q8)  Create a line plot with multiple lines using Matplotlib.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [10, 20, 30, 40]
y2 = [15, 25, 35, 45]

plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Multiple Line Plot")
plt.show()

# %% [markdown]
# Q9)  Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold.

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["A", "B", "C", "D"],
    "marks": [50, 75, 40, 90]
})

filtered = df[df["marks"] > 60]
print(filtered);
# Out:
#   name  marks
# 1    B     75
# 3    D     90

# %% [markdown]
# Q10)  Create a histogram using Seaborn to visualize a distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = [10, 20, 20, 30, 40, 40, 40, 50]

sns.histplot(data)
plt.title("Histogram")
plt.show()

# %% [markdown]
# Q11)  Perform matrix multiplication using NumPy.

# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

result = np.dot(A, B)
print("Matrix Multiplication Result:\n", result)
# Out:
# Matrix Multiplication Result:
#  [[19 22]
#  [43 50]]

# %% [markdown]
# Q12)  Use Pandas to load a CSV file and display its first 5 rows.

# %%
import pandas as pd

df = pd.read_csv("california_housing_test.csv")
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Q13)  Create a 3D scatter plot using Plotly.

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame({
    "x": [1, 2, 3, 4],
    "y": [10, 20, 30, 40],
    "z": [5, 15, 25, 35]
})

fig = px.scatter_3d(df, x="x", y="y", z="z", title="3D Scatter Plot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
